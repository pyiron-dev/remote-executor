# %%
from executorlib import FileExecutor

# %%
from executorlib.cache.shared import execute_in_subprocess

# %%
from pysqa import QueueAdapter

# %%
def my_funct(a, b):
    return a+b

# %%
def execute_with_pysqa(command, task_dependent_lst=[]):
    qa = QueueAdapter(directory="resources/queues")
    return qa.submit_job(command=" ".join(command), working_directory=".")

# %%
with FileExecutor(execute_function=execute_with_pysqa) as exe:
    fs1 = exe.submit(my_funct, 1, b=2)
    fs2 = exe.submit(my_funct, 1, b=fs1)
    print(fs2.done(), fs2.result(), fs2.done())
# Out:
# False 4 True

# %%
# !flux jobs -a
# Out:
#        JOBID USER     NAME       ST NTASKS NNODES     TIME INFO
#     ƒ2JMYVmZ jovyan   None       CD      1      1   2.248s jupyter-pyiron-2ddev-2dremote-2dexecutor-2df2h8rh0p
#     ƒ2D972HD jovyan   None       CD      1      1   2.368s jupyter-pyiron-2ddev-2dremote-2dexecutor-2df2h8rh0p
